# %%
import pandas as pd

# %%
df = pd.read_sas('CBC_J.XPT')

# %%
df.head()
# Out:
#       SEQN  LBXWBCSI  LBXLYPCT  LBXMOPCT  LBXNEPCT  LBXEOPCT  LBXBAPCT  \
# 0  93703.0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  93704.0       7.4      47.8       8.0      42.6       1.0       0.7
# 2  93705.0       8.6      40.0       7.4      48.8       2.9       1.0
# 3  93706.0       6.1      24.6       9.1      61.4       4.3       0.8
# 4  93707.0      11.2      37.1       6.2      54.7       1.6       0.5
#
#    LBDLYMNO  LBDMONO  LBDNENO  ...  LBXRBCSI  LBXHGB  LBXHCT  LBXMCVSI  \
# 0       NaN      NaN      NaN  ...       NaN     NaN     NaN       NaN
# 1       3.5      0.6      3.2  ...      4.25    13.1    37.0      87.0
# 2       3.4      0.6      4.2  ...      5.48    11.9    36.7      67.0
# 3       1.5      0.6      3.7  ...      5.24    16.3    47.0      89.7
# 4       4.2      0.7      6.1  ...      5.02    14.5    42.1      83.9
#
#    LBXMCHSI  LBXMC  LBXRDW  LBXPLTSI  LBXMPSI       LBXNRBC
# ...

# %%
df.shape
# Out:
# (8366, 22)

# %%
df.isna().sum()
# Out:
# SEQN          0
# LBXWBCSI    838
# LBXLYPCT    843
# LBXMOPCT    843
# LBXNEPCT    843
# LBXEOPCT    843
# LBXBAPCT    843
# LBDLYMNO    843
# LBDMONO     843
# LBDNENO     843
# LBDEONO     843
# LBDBANO     843
# LBXRBCSI    838
# LBXHGB      838
# LBXHCT      838
# LBXMCVSI    838
# LBXMCHSI    838
# LBXMC       838
# LBXRDW      838
# LBXPLTSI    838
# LBXMPSI     838
# LBXNRBC     843
# dtype: int64

# %%
df_m = df[1:6]

# %%
df_m
# Out:
#       SEQN  LBXWBCSI  LBXLYPCT  LBXMOPCT  LBXNEPCT  LBXEOPCT  LBXBAPCT  \
# 1  93704.0       7.4      47.8       8.0      42.6       1.0       0.7
# 2  93705.0       8.6      40.0       7.4      48.8       2.9       1.0
# 3  93706.0       6.1      24.6       9.1      61.4       4.3       0.8
# 4  93707.0      11.2      37.1       6.2      54.7       1.6       0.5
# 5  93708.0       6.0      31.3       6.8      59.4       2.0       0.7
#
#    LBDLYMNO  LBDMONO  LBDNENO  ...  LBXRBCSI  LBXHGB  LBXHCT  LBXMCVSI  \
# 1       3.5      0.6      3.2  ...      4.25    13.1    37.0      87.0
# 2       3.4      0.6      4.2  ...      5.48    11.9    36.7      67.0
# 3       1.5      0.6      3.7  ...      5.24    16.3    47.0      89.7
# 4       4.2      0.7      6.1  ...      5.02    14.5    42.1      83.9
# 5       1.9      0.4      3.6  ...      4.59    13.2    39.9      86.8
#
#    LBXMCHSI  LBXMC  LBXRDW  LBXPLTSI  LBXMPSI       LBXNRBC
# ...

# %%
df_m.index.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
date = ['21-6-21', '22-6-21', '23-6-21', '25-6-21', '30-6-21']
df_m["date"]=pd.to_datetime(date)
# Out:
# <ipython-input-31-d97154470659>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m["date"]=pd.to_datetime(date)

# %%
df_m
# Out:
#       SEQN  LBXWBCSI  LBXLYPCT  LBXMOPCT  LBXNEPCT  LBXEOPCT  LBXBAPCT  \
# 1  93704.0       7.4      47.8       8.0      42.6       1.0       0.7
# 2  93705.0       8.6      40.0       7.4      48.8       2.9       1.0
# 3  93706.0       6.1      24.6       9.1      61.4       4.3       0.8
# 4  93707.0      11.2      37.1       6.2      54.7       1.6       0.5
# 5  93708.0       6.0      31.3       6.8      59.4       2.0       0.7
#
#    LBDLYMNO  LBDMONO  LBDNENO  ...  LBXHGB  LBXHCT  LBXMCVSI  LBXMCHSI  LBXMC  \
# 1       3.5      0.6      3.2  ...    13.1    37.0      87.0      30.8   35.4
# 2       3.4      0.6      4.2  ...    11.9    36.7      67.0      21.7   32.4
# 3       1.5      0.6      3.7  ...    16.3    47.0      89.7      31.1   34.7
# 4       4.2      0.7      6.1  ...    14.5    42.1      83.9      28.9   34.4
# 5       1.9      0.4      3.6  ...    13.2    39.9      86.8      28.8   33.1
#
#    LBXRDW  LBXPLTSI  LBXMPSI       LBXNRBC       date
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df_m.date.dt.day, df_m['LBXRBCSI'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df_m.date.dt.day, df_m['LBXHGB'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df_m.date.dt.day, df_m['LBXWBCSI'])
plt.show()
